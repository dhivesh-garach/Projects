# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Dhivesh_Personal/ABADS Course Files/WEEK 7 - Analyzing Data Using Pandas and Numpy/Graded Assessment/DataSet_Supermarket_Sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.groupby("Product line")["cogs"].max()
# Out:
# Product line
# Electronic accessories    897.57
# Fashion accessories       993.00
# Food and beverages        985.20
# Health and beauty         905.00
# Home and lifestyle        975.00
# Sports and travel         954.40
# Name: cogs, dtype: float64

# %%
df[["Total"]].max()
# Out:
# Total    1042.65
# dtype: float64

# %%
df.groupby(["City", "Product line"])[["Total"]].count()
# Out:
#                                   Total
# City      Product line
# Mandalay  Electronic accessories     55
#           Fashion accessories        62
#           Food and beverages         50
#           Health and beauty          53
#           Home and lifestyle         50
#           Sports and travel          62
# Naypyitaw Electronic accessories     55
#           Fashion accessories        65
#           Food and beverages         66
#           Health and beauty          52
#           Home and lifestyle         45
#           Sports and travel          45
# Yangon    Electronic accessories     60
#           Fashion accessories        51
#           Food and beverages         58
#           Health and beauty          47
#           Home and lifestyle         65
#           Sports and travel          59

# %%
df["Product line"].drop_duplicates()
# Out:
# 0          Health and beauty
# 1     Electronic accessories
# 2         Home and lifestyle
# 4          Sports and travel
# 9         Food and beverages
# 10       Fashion accessories
# Name: Product line, dtype: object

# %%
df["Invoice ID"].is_unique
# Out:
# True

# %%
df[df["Payment"] == "Ewallet"].shape
# Out:
# (345, 17)

# %%
(345/1000)*100
# Out:
# 34.5

# %%
#df.groupby("Product line")["Payment" == "Ewallet"].count()

# %%
a = df[["Branch","Customer type", "Total"]]
a
# Out:
#     Branch Customer type      Total
# 0        A        Member   548.9715
# 1        C        Normal    80.2200
# 2        A        Normal   340.5255
# 3        A        Member   489.0480
# 4        A        Normal   634.3785
# ..     ...           ...        ...
# 995      C        Normal    42.3675
# 996      B        Normal  1022.4900
# 997      A        Member    33.4320
# 998      A        Normal    69.1110
# 999      A        Member   649.2990
#
# [1000 rows x 3 columns]

# %%
temp = a[
    (a["Customer type"] == "Member") & (a["Branch"] == "A")

]

# %%
temp["Total"].sum()
# Out:
# 53637.4755

# %%
a.shape
# Out:
# (1000, 3)

# %%
branch_cus = df.loc[
    (df["Customer type"] == "Member") & (df["Branch"]== "A")
                    
    , ["Branch", "Customer type", "Total", "cogs"]

]

# %%
branch_cus.describe()
# Out:
#             Total        cogs
# count  167.000000  167.000000
# mean   321.182488  305.888084
# std    229.792596  218.850091
# min     19.246500   18.330000
# 25%    146.107500  139.150000
# 50%    262.458000  249.960000
# 75%    486.785250  463.605000
# max    951.825000  906.500000

# %%
df.groupby(["Gender","Payment"])[["Payment"]].count()
# Out:
#                     Payment
# Gender Payment
# Female Cash             178
#        Credit card      163
#        Ewallet          160
# Male   Cash             166
#        Credit card      148
#        Ewallet          185

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df[["Product line", "Payment"]].groupby("Payment").count()
# Out:
#              Product line
# Payment
# Cash                  344
# Credit card           311
# Ewallet               345
